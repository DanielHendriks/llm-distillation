# %%
from analyze_utils import *

path = "/home/stud03/DanielH/llm_outputs/rationales_revised/cqa-train"
df = read_sharded_dataset(path)

df.loc[:,["question", "choices", "answer", "few_shot_positive_rationale", "few_shot_revision"]].head(5)
# Out:
#                                                                                                                     question  \
# 0             "There are 10 apples on an apple tree.  Three fall off.  Now there are X apples."  What is this an example of?
# 1  A John is a bum.  Much like the stereotype, he lives near this sort of transportation infrastructure. Where does he live?
# 2                                   A bad person places little value on being honest, acting without pretense or being what?
# 3                                                                             A bald eagle flies over St. Paul, where is it?
# 4                          A battleship is a powerful vessel.  If you need something similar but faster, what would you use?
#
#                                                        choices        answer  \
# 0  [park, coloring book, garden center, math problem, gravity]  math problem
# ...

# %%
visualize_data(df, cols=['few_shot_revision'])
